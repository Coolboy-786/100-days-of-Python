# %%
import pandas as pd

# %%
def is_odd(num):
    """
    this function is created by Eshan,
    it used to check whether a number is odd or even
    created on 15th april 2026
    """
    if type(num) == int:
        if num%2 !=0:
            return "odd"
        else:
            return "even"
    else:
        return "Not allowed"

# %%
is_odd("hello")
# Out:
# 'Not allowed'

# %%
is_odd(3)
# Out:
# 'odd'

# %%
is_odd(0)
# Out:
# 'even'

# %%
print(is_odd.__doc__)
# Out:
#     this function is created by Eshan,
#     it used to check whether a number is odd or even
#     created on 15th april 2026

# %% [markdown]
# # Types of arguments
#
# ### 1) Default Arguments
# ### 2) Positional Arguments
# ### 3) Keyword Arguments
# ### 4) Arbitary Arguments

# %%
def flexi(*num):
    pro = 1
    for i in num:
        pro=pro*i
    print(pro)

# %%
flexi(3)
# Out:
# 3

# %%
flexi(1,2,3,4,5,6,6)
# Out:
# 4320

# %%
flexi(1,2,3,4,5,6)
# Out:
# 720

# %% [markdown]
# # Global vs local variables

# %%
def g(y):
    print(x)
    print(x+1)

x=5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
#changing global variable inside the function

def h(y):
    global z
    z+=1

z=5
g(z)
print(z)
# Out:
# 5
# 6
# 5

# %%
#Nested functions

def g(x):
    def h(x):
        x='abc'
        print('in h(x) : x = ',x)
    x=x+1
    print('in g(x) : x = ',x)
    h(x)
    return x

x=3
z=g(x)
# Out:
# in g(x) : x =  4
# in h(x) : x =  abc

# %%
def g(x):
    def h(x):
        x=x+1
        print('in h(x) : x = ',x)
    x=x+1
    print('in g(x) : x = ',x)
    h(x)
    return x

x=3
z=g(x)
print(z)
# Out:
# in g(x) : x =  4
# in h(x) : x =  5
# 4

# %%
 l = [1,2,3,g(x)]
# Out:
# in g(x) : x =  4
# in h(x) : x =  5

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
def pow(x):
    return x**2

l1 = (1,2,3,4,pow(3))

# %%
l1
# Out:
# (1, 2, 3, 4, 9)

# %%
l1(-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 l1(-1)
#
# TypeError: 'tuple' object is not callable

# %%
#returing function inside the function

def f():
    def x(a,b):
        return a+b
    return x
val = f()(3,4)
print(val)
# Out:
# 7

# %% [markdown]
# # Benefits of functions
#
# ### code Resusability
# ### code Readability
