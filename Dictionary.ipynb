# %% [markdown]
# # Dictionary

# %% [markdown]
# ### 1) Just like sets , Dictionary don't have indexing
# ### 2) it is a mutable data type
# ### 3) Keys are Immutable and values are mutable
# ### 4) Keys should be unique

# %%
D = {}

# %%
D
# Out:
# {}

# %%
d1 = {'name' : 'Eshan', 'Surname': 'Jain', 'age' : '30'}

# %%
d1
# Out:
# {'name': 'Eshan', 'Surname': 'Jain', 'age': '30'}

# %%
d2 = d1.copy()

# %%
d2
# Out:
# {'name': 'Eshan', 'Surname': 'Jain', 'age': '30'}

# %%
d2['Gender'] = 'male'

# %%
d2
# Out:
# {'name': 'Eshan', 'Surname': 'Jain', 'age': '30', 'Gender': 'male'}

# %%
d2['name']
# Out:
# 'Eshan'

# %%
d3 = {'Name': 'Eshan','surname': 'jain','Marks': {'M1': '12','DS' : '43','Maths': '74'}}

# %%
d3
# Out:
# {'Name': 'Eshan',
#  'surname': 'jain',
#  'Marks': {'M1': '12', 'DS': '43', 'Maths': '74'}}

# %%
d3['Marks']['Maths']
# Out:
# '74'

# %%
d3['Marks']['Eng']=32

# %%
d3
# Out:
# {'Name': 'Eshan',
#  'surname': 'jain',
#  'Marks': {'M1': '12', 'DS': '43', 'Maths': '74', 'Eng': 32}}

# %%
d3.keys()
# Out:
# dict_keys(['Name', 'surname', 'Marks'])

# %%
d3.values()
# Out:
# dict_values(['Eshan', 'jain', {'M1': '12', 'DS': '43', 'Maths': '74', 'Eng': 32}])

# %%
d3['Marks'].values()
# Out:
# dict_values(['12', '43', '74', 32])

# %%
for i in d3:
    print(i,d3[i])
# Out:
# Name Eshan
# surname jain
# Marks {'M1': '12', 'DS': '43', 'Maths': '74', 'Eng': 32}

# %%
len(d3)
# Out:
# 3

# %%
max(d3)
# Out:
# 'surname'

# %%
min(d3)
# Out:
# 'Marks'
