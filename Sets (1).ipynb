# %% [markdown]
# # Sets

# %% [markdown]
# ## Rules for sets
#
# ### 1) Sets do not allow duplicates
# ### 2) Sets have no indexing/slicing
# ### 3) Sets do not allow mutable datatypes
# ### 1) Sets is a mutable datatype

# %%
# create sets

s1 = s1{}
# Out:
#   Cell In[1], line 3
#     s1 = s1{}
#            ^
# SyntaxError: invalid syntax

# %%
s1 = set()

# %%
s1
# Out:
# set()

# %%
type(s1)
# Out:
# set

# %%
s1 = {1,2,3,4}

# %%
s2 = {1,2,3,{4,5}} #no 2d and 3d operations are possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s2 = {1,2,3,{4,5}} #no 2d and 3d operations are possible
#
# TypeError: unhashable type: 'set'

# %%
s3 = {1,2,4,"hello"}

# %%
s3
# Out:
# {1, 2, 4, 'hello'}

# %%
s4 = {(1,2,3),"hello"}

# %%
s4
# Out:
# {(1, 2, 3), 'hello'}

# %%
#Accessing 

s3[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 #Accessing
# ----> 3 s3[::-1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### sets cannot be accessed or edited

# %%
#add 

s3.add(5)

# %%
s3
# Out:
# {1, 2, 4, 5, 'hello'}

# %%
#delete

del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
s3.remove("hello")

# %%
s3
# Out:
# {1, 2, 4, 5}

# %%
s3.pop()
# Out:
# 1

# %% [markdown]
# ### indexing is according to hashing

# %%
for i in s3:
    print(i)
# Out:
# 2
# 4
# 5

# %%
1 in s3
# Out:
# False

# %%
2 in s3
# Out:
# True

# %%
#functions 

len(s3)
# Out:
# 3

# %%
max(s3)
# Out:
# 5

# %%
min(s3)
# Out:
# 2

# %%
sum(s3)
# Out:
# 11

# %%
s3
# Out:
# {2, 4, 5}

# %%
s4 = {1,2,4,6,7}

# %% [markdown]
# ### sets are like sets in mathematics

# %%
s4.union(s3)
# Out:
# {1, 2, 4, 5, 6, 7}

# %%
s4.intersection(s3)
# Out:
# {2, 4}

# %%
s4.difference(s3)
# Out:
# {1, 6, 7}

# %%
s3.difference(s4)
# Out:
# {5}

# %%
s3.symmetric_difference(s4)
# Out:
# {1, 5, 6, 7}

# %%
s4.symmetric_difference(s3)
# Out:
# {1, 5, 6, 7}

# %%
s3.isdisjoint(s4)
# Out:
# False

# %%
s3.issubset(s4)
# Out:
# False

# %%
s4.issuperset(s3)
# Out:
# False
