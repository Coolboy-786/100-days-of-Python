# %%
help('module')
# Out:
# No Python documentation found for 'module'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
help('print')
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
x = 12.312

type(x)
# Out:
# float

# %%
abs(x)
# Out:
# 12.312

# %%
abs(-1-3)
# Out:
# 4

# %%
pow(2,5)
# Out:
# 32

# %%
min("encylopedia")
# Out:
# 'a'

# %%
max('encylopedia')
# Out:
# 'y'

# %%
divmod(12,5)
# Out:
# (2, 2)

# %%
id(x)
# Out:
# 2406749973424

# %%
oct(3)
# Out:
# '0o3'

# %%
bin(4)
# Out:
# '0b100'

# %%
sum([1,2,3,44,5])
# Out:
# 55

# %%
# ?module
# Out:
# Object `module` not found.

# %%
import math as m

# %%
m.tan(45)
# Out:
# 1.6197751905438615

# %%
m.sqrt(1231)
# Out:
# 35.08560958569767

# %%
round(m.sqrt(1231),3)
# Out:
# 35.086

# %%
import random as rand

# %%
rand.randint(1,23)
# Out:
# 4

# %%
y = rand.shuffle([1,2,34,213,12])

# %%
y

# %%
rand.shuffle([1,2,3,42341,91])

# %%
import time as t

# %%
t.time()
# Out:
# 1775675151.5196283

# %%
t.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=4, tm_mday=8, tm_hour=20, tm_min=6, tm_sec=8, tm_wday=2, tm_yday=98, tm_isdst=1)

# %%
t.ctime()
# Out:
# 'Wed Apr  8 20:06:25 2026'

# %%
print("Hello")
t.sleep(3)
print("world")
# Out:
# Hello
# world

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ESHAN JAIN\\100 days of python'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'builtin functions and modules.ipynb',
#  'python basics.ipynb']

# %%
def add(x,y):
    return x+y

# %%
add(-12,32)
# Out:
# 20
