# %%
c = str("Hello World!")
c #string creation
# Out:
# 'Hello World!'

# %%
c[0] #string indexing
# Out:
# 'H'

# %%
c[-1]
# Out:
# '!'

# %%
c[ : :-1]#string slicing
# Out:
# '!dlroW olleH'

# %%
c[1:5:-1]
# Out:
# ''

# %%
c[-6:-1:-1]
# Out:
# ''

# %%
c[-1:-6:-1]
# Out:
# '!dlro'

# %% [markdown]
# # string editing and deletion

# %%
c = "Hello"

# %%
c
# Out:
# 'Hello'

# %%
c[0] = 'l'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 c[0] = 'l'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## strings are immutable

# %%
c = 'World!'

# %%
#but strings can be reassigned

# %%
del c

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c = 'World!'

# %%
del c[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 del c[:]
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# #### strings dont' support item deletion as it is immutable

# %%
for i in range(1,10):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********

# %% [markdown]
# ##### string operations

# %%
#concatenation

"Hello" + "World"
# Out:
# 'HelloWorld'

# %%
#comparison

"cat" > "Cat"
# Out:
# True

# %%
"hello" and "Hello"
# Out:
# 'Hello'

# %%
"hello" and "world"
# Out:
# 'world'

# %%
"hello" or "world"
# Out:
# 'hello'

# %%
not "hello"
# Out:
# False

# %%
#false is empty string

not "world"
# Out:
# False

# %%
for i in c[::-1]:
    print(i)
# Out:
# !
# d
# l
# r
# o
# W

# %%
"i" in c
# Out:
# False

# %%
"w" in c
# Out:
# False

# %%
"l" in c
# Out:
# True

# %%
"ll" in c
# Out:
# False

# %%
c = "hello"

# %%
"ll" in c
# Out:
# True

# %%
"e" | "o" in c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 "e" | "o" in c
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %% [markdown]
# # function in strings

# %%
x = "encyclopedia"

len(x)
# Out:
# 12

# %%
min(x)
# Out:
# 'a'

# %%
max(x)
# Out:
# 'y'

# %%
sorted(x)
# Out:
# ['a', 'c', 'c', 'd', 'e', 'e', 'i', 'l', 'n', 'o', 'p', 'y']

# %%
sorted(x,reverse = True)
# Out:
# ['y', 'p', 'o', 'n', 'l', 'i', 'e', 'e', 'd', 'c', 'c', 'a']

# %%
x[::-1]
# Out:
# 'aidepolcycne'

# %%
if sorted(x) == sorted(x[::-1]):
    print("yeah")
# Out:
# yeah

# %%
x.capitalize()
# Out:
# 'Encyclopedia'

# %%
k = "hello how are you? I love this"
for i in k.split():
    k = k.replace(i, i.capitalize())
print(k)
# Out:
# Hello How Are You? I Love This

# %%
k.title()
# Out:
# 'Hello How Are You? I Love This'

# %%
k
# Out:
# 'Hello How Are You? I Love This'

# %%
k = "hello how are you? I love this"

# %%
k.title() #capitalizes every starting charater of a word
# Out:
# 'Hello How Are You? I Love This'

# %%
k.capitalize()
# Out:
# 'Hello how are you? i love this'

# %%
k.upper()
# Out:
# 'HELLO HOW ARE YOU? I LOVE THIS'

# %%
k.lower()
# Out:
# 'hello how are you? i love this'

# %%
k = "Hello world"

k.swapcase()  #upper to lower and lower to upper
# Out:
# 'hELLO WORLD'

# %%
#count -- counts the number of occurences

k.count("i")
# Out:
# 0

# %%
k.count("l")
# Out:
# 3

# %%
#find/index

k.find("o")
# Out:
# 4

# %%
k.index("x")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 k.index("x")
#
# ValueError: substring not found

# %%
k.find("y")
# Out:
# -1

# %%
k.endswith("d")
# Out:
# True

# %%
k.startswith("w")
# Out:
# False

# %%
bio = "hello my name is {name} and my age is {age}"

# %%
bio.format("Eshan",26)
# Out:
# 'hello my name is Eshan and my age is 26'

# %%
bio.format(name = "jain", age = 26)
# Out:
# 'hello my name is jain and my age is 26'

# %%
x = "123.45"

x.isnumeric()
# Out:
# False

# %%
x.isdecimal()
# Out:
# False

# %%
x.isalpha()
# Out:
# False

# %%
x.isalnum()
# Out:
# False

# %%
x.isidentifier()
# Out:
# False

# %%
#splitting -->  converts a string to list

k.split()
# Out:
# ['Hello', 'world']

# %%
bio.split("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 bio.split("")
#
# ValueError: empty separator

# %%
bio.split()
# Out:
# ['hello', 'my', 'name', 'is', '{name}', 'and', 'my', 'age', 'is', '{age}']

# %%
bio.format(name = "Eshan", age = 26).split()
# Out:
# ['hello', 'my', 'name', 'is', 'Eshan', 'and', 'my', 'age', 'is', '26']

# %%
bio.split(",")
# Out:
# ['hello my name is {name} and my age is {age}']

# %%
bio.split("name")
# Out:
# ['hello my ', ' is {', '} and my age is {age}']

# %%
# join --> converst list back to string

"".join(["h","e","l","l","o"])
# Out:
# 'hello'

# %%
#replace()
