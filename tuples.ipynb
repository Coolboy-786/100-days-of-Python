# %% [markdown]
# ## tuples

# %%
#empty tuple 

t1 = ()

# %%
t1
# Out:
# ()

# %%
t2 = (1,2,3,4,5)

# %%
t3 = tuple("goa")

# %%
t3
# Out:
# ('g', 'o', 'a')

# %%
t2[:3]
# Out:
# (1, 2, 3)

# %%
t2[::-1]
# Out:
# (5, 4, 3, 2, 1)

# %% [markdown]
# #### tuples are immutable and cannot be edited unlike lists

# %%
del t3 # deleting tuples
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 del t3 # deleting tuples
#
# NameError: name 't3' is not defined

# %%
t3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t3
#
# NameError: name 't3' is not defined

# %%
t2+t2[::-1]
# Out:
# (1, 2, 3, 4, 5, 5, 4, 3, 2, 1)

# %%
len(t2)
# Out:
# 5

# %%
max(t2)
# Out:
# 5

# %%
min(t2)
# Out:
# 1

# %%
sorted(t2, reverse = True)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## tuples are important and used mai
